# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import numpy as np

dist_data = pd.read_csv('S:/Hackathons/EY/results/unscaled_dist_data.csv')
import warnings
warnings.filterwarnings('ignore')
indexed =pd.read_csv('S:/Hackathons/EY/results/indexed1.csv')


dist_data.head()
dist_data1 = dist_data.copy()

# %%
scaler1 = MinMaxScaler()
scaler2 = MinMaxScaler()

dist_data1['temp'] = np.power(dist_data1['deceased']*dist_data1['confirmed'],0.5)
dist_data1['temp'] = scaler2.fit_transform(dist_data1[['temp']])
sns.scatterplot(indexed['index'],dist_data1['temp'])
# Out:
# <AxesSubplot:xlabel='index', ylabel='temp'>

# %%
scaler1 = MinMaxScaler()
scaler2 = MinMaxScaler()

dist_data1['deceased'] = scaler1.fit_transform(dist_data1[['deceased']])
dist_data1['confirmed'] = scaler2.fit_transform(dist_data1[['confirmed']])
dist_data1['temp'] = np.power(dist_data1['deceased']*dist_data1['confirmed'],0.5)

sns.scatterplot(indexed['index'],dist_data1['temp'])
# Out:
# <AxesSubplot:xlabel='index', ylabel='temp'>

# %%
dist_data1['temp'] = dist_data1['deceased']/dist_data1['confirmed']
sns.scatterplot(indexed['index'],dist_data1['temp'])
# Out:
# <AxesSubplot:xlabel='index', ylabel='temp'>

# %%
dist_data['temp'] =dist_data1['deceased']/dist_data1['confirmed']
sns.scatterplot(indexed['index'],dist_data['temp'])
# Out:
# <AxesSubplot:xlabel='index', ylabel='temp'>

# %%
dist_data1['covid_index'] = np.power(dist_data1['deceased']*dist_data1['confirmed'],0.5)
dist_data1['dist_index'] = indexed['index']
dist_data1.to_csv('S:/Hackathons/EY/results/covid-index.csv',index = False)
