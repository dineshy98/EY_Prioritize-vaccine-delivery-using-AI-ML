# %%
import geopandas as gpd

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
shapefile = gpd.read_file('S:/Hackathons/EY/vis/c44c9b96-f570-4ee3-97f1-ebad64efa4c2202044-1-1rb4x6s.8xx6.shp')
district_wise = pd.read_csv('S:/Hackathons/EY/datasets/cases/district_wise.csv')
main = pd.read_csv('S:/Hackathons/EY/datasets/main.csv')
shapefile.head()
# Out:
#    objectid statecode    statename state_ut distcode    distname  \
# 0         1        27  MAHARASHTRA    STATE      499     Jalgaon
# 1         2        27  MAHARASHTRA    STATE      516      Nashik
# 2         3        27  MAHARASHTRA    STATE      509  Chandrapur
# 3         4        27  MAHARASHTRA    STATE      510    Yavatmal
# 4         5        27  MAHARASHTRA    STATE      511      Nanded
#
#      st_area(sh    st_length( countrynam  \
# 0  1.353967e+10  8.464308e+05      India
# 1  1.771358e+10  9.720056e+05      India
# 2  1.294532e+10  7.410244e+05      India
# 3  1.547940e+10  1.014942e+06      India
# 4  1.186387e+10  1.131732e+06      India
#
#                                             geometry
# 0  POLYGON ((75.23335 21.41481, 75.23469 21.41453...
# 1  POLYGON ((74.13013 20.86311, 74.13215 20.86160...
# 2  POLYGON ((79.75755 20.73462, 79.76047 20.73463...
# 3  POLYGON ((78.26132 20.69735, 78.26276 20.69717...
# 4  POLYGON ((78.05387 19.92452, 78.05449 19.92435...

# %%
main.head()
# Out:
#             state      District_Key  population_x     area     density  \
# 0  Andhra Pradesh      AP_Anantapur   4540646.280  19130.0  237.357359
# 1  Andhra Pradesh       AP_Chittoor   4637560.416  15152.0  306.069193
# 2  Andhra Pradesh  AP_East Godavari   5728522.488  10807.0  530.075182
# 3  Andhra Pradesh         AP_Guntur   5436823.760  11391.0  477.291174
# 4  Andhra Pradesh         AP_Kadapa   3207590.688  15359.0  208.841115
#
#    Confirmed  Active  Recovered  Deceased  Migrated_Other  population_y  \
# 0      67121     149      66377       595               0    42332781.5
# 1      85381     452      84092       837               0    42332781.5
# 2     123267     489     122142       636               0    42332781.5
# 3      74228     621      72947       660               0    42332781.5
# 4      54774     122      54197       455               0    42332781.5
#
#    No.CCE  No.CCP  CCE per lakh population  CCE per CCP
# ...

# %%
shapefile.plot()
# Out:
# <AxesSubplot:>

# %%
for i in range(shapefile.shape[0]): shapefile['statename'][i] = shapefile['statename'][i].title()

shapefile['statename'].replace({'Andaman & Nicobar': 'Andaman and Nicobar Islands',  'Dadra & Nagar Have': 'Dadra and Nagar Haveli and Daman and Diu','Daman & Diu' : 'Dadra and Nagar Haveli and Daman and Diu','Jammu & Kashmir' : 'Jammu and Kashmir'}, inplace=True)


shapefile['distname'].replace({'Baramula' : 'Baramulla',
                         'Bandipore' : 'Bandipora',
                         'Badgam' : 'Budgam',
                         'Shupiyan' : 'Shopiyan',
'Sahibzada Ajit Singh Nag*' : 'S.A.S. Nagar',
'Firozpur': 'Ferozepur',
'Lahul & Spiti' : 'Lahaul and Spiti',
'Charki Dadri': 'Charkhi Dadri',
'Central' : 'Central Delhi',
'East' : 'East Delhi',
'North' : 'North Delhi', 
'South West' : 'South West Delhi', 
'South' : 'South Delhi', 
'North East' : 'North East Delhi', 
'West' : 'West Delhi', 
'South East': 'South East Delhi', 
'North West' : 'North West Delhi','Jhunjhunun': 'Jhunjhunu', 
'Jalor' : 'Jalore', 'Chittaurgarh' : 'Chittorgarh', 'Dhaulpur': 'Dholpur','Chota Udaipur': 'Chhota Udaipur', 'Kachchh' : 'Kutch', 'The Dangs' : 'Dang', 'Banas Kantha' : 'Banaskantha', 'Ahmadabad' : 'Ahmedabad', 'Sabar Kantha' : 'Sabarkantha', 'Dohad' : 'Dahod', 'Mahesana' : 'Mehsana', 'Panch Mahals' : 'Panchmahal', 'Faizabad' : 'Ayodhya', 'Kheri' : 'Lakhimpur Kheri', 
'Bara Banki': 'Barabanki', 'Mahrajganj' : 'Maharajganj','Pashchim Champaran': 'West Champaran', 'Mahrajganj' : 'Maharajganj',
'Pashchim Champaran': 'West Champaran', 'Kaimur (bhabua)': 'Kaimur', 'Purba Champaran': 'East Champaran',
'Purbi Singhbhum': 'East Singhbhum', 'Pashchimi Singhbhum': 'West Singhbhum', 'Saraikela-kharsawan': 'Saraikela-Kharsawan', 'Kodarma': 'Koderma',
'Narsimhapur': 'Narsinghpur', 'West Nimar': 'Khargone', 'East Nimar': 'Khandwa',
'Janjgir - Champa' : 'Janjgir Champa','Almora\n': 'Almora','Garhwal': 'Pauri Garhwal', 'Hardwar': 'Haridwar', 
'Darjiling': 'Darjeeling','Maldah' : 'Malda',   'North Twenty Four Pargan*' : 'North 24 Parganas', 
'Medinipur West' : 'Paschim Medinipur', 'Puruliya': 'Purulia','South Twenty Four Pargan*' : 'South 24 Parganas',
'North  District': 'North District','South Salmara Mancachar': 'South Salmara Mankachar','Anugul': 'Angul', 'Jajapur': 'Jajpur',  'Jagatsinghapur' : 'Jagatsinghpur', 'Baleshwar': 'Balasore', 'Baudh': 'Boudh', 
'Debagarh' : 'Deogarh', 'Ahmadnagar' : 'Ahmednagar', 'Gondiya' : 'Gondia', 'Bid' : 'Beed', 'Buldana': 'Buldhana','Jagitial' : 'Jagtial',  'Jayashankar' : 'Jayashankar Bhupalapally',  'Jangoan': 'Jangaon', 'Kumuram Bheem Asifabad' : 'Komaram Bheem',
'Y.S.R.': 'Y.S.R. Kadapa',  'Sri Potti Sriramulu Nell*' : 'S.P.S. Nellore','Bangalore' : 'Bengaluru Urban', 'The Nilgiris': 'Nilgiris', 
'Kanniyakumari' : 'Kanyakumari','North  & Middle Andaman': 'North and Middle Andaman', 'Dadra & Nagar Haveli': 'Dadra and Nagar Haveli'},inplace = True)

# %%
def compare(col1,col2):
    col1 = col1.astype(str)
    col2 = col2.astype(str)
    s1 = set(col1) 
    s2 = set(col2)
    return s1.symmetric_difference(s2)



dict_state_code = dict(zip(district_wise['State'].unique(),district_wise['State_Code'].unique()))


shapefile_keys = shapefile[['statename','distname']]
shapefile_keys['state_code'] = shapefile_keys['statename']
shapefile_keys['state_code'].replace(dict_state_code,inplace = True)

shapefile_keys['dist_code'] = shapefile_keys['state_code'] + '_' + shapefile_keys['distname']



compare(shapefile_keys['dist_code'] ,main['District_Key'])
# Out:
# <ipython-input-13-f34a09f24108>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shapefile_keys['state_code'] = shapefile_keys['statename']
# <ipython-input-13-f34a09f24108>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shapefile_keys['dist_code'] = shapefile_keys['state_code'] + '_' + shapefile_keys['distname']
# {'AN_Nicobar',
#  'AN_Nicobars',
#  'AP_Kadapa',
#  'AP_S.P.S. Nellore',
#  'AP_Sri Potti Sriramulu Nellore',
#  'AP_Y.S.R. Kadapa',
#  'AR_Kra Daadi',
#  'AR_Lepa Rada',
# ...

# %%
dist_replace_on_main = {
 'AN_Nicobars':'AN_Nicobar',
 'AP_S.P.S. Nellore':'AP_Sri Potti Sriramulu Nellore',
 'AP_Y.S.R. Kadapa': 'AP_Kadapa',
 'AS_Biswanath' :'AS_Bishwanath',
 'AS_South Salmara Mankachar':'AS_South Salmara',
 'CT_Bametara':'CT_Bemetara',
 'CT_Dakshin Bastar Dantewada':'CT_Dantewada',
 'CT_Gaurela Pendra Marwahi':'CT_Gaurella-Pendra-Marwahi',
 'CT_Janjgir Champa':'CT_Janjgir-Champa',
 'CT_Kabeerdham':'CT_Kabirdham',

 'GJ_Chhota Udaipur':'GJ_Chhota Udepur',
 'GJ_Devbhumi Dwarka':'GJ_Devbhoomi Dwarka',

 'HR_Gurugram': 'HR_Gurgaon',
 'HR_Hisar':'HR_Hissar',

 'HR_Yamuna Nagar':'HR_Yamunanagar',
 'JH_Hazaribag':'JH_Hazaribagh',
 'JH_Saraikela-Kharsawan':'JH_Seraikela Kharsawan',

 'JK_Budgam': 'JK_Badgam',
 'JK_Punch':'JK_Poonch',
  'JK_Shopiyan':'JK_Shopian',

 'KA_Bagalkote':'KA_Bagalkot',
 'KA_Bengaluru Rural' : 'KA_Bangalore Rural',
 'KA_Bengaluru Urban' : 'KA_Bangalore Urban',
 'KA_Belagavi':'KA_Belgaum',


 'KA_Chikkamagaluru':'KA_Chikmagalur',
 'KA_Vijayapura':'KA_Bijapur',
 'KA_Kalaburagi':'KA_Gulbarga',
 'KA_Mysuru':'KA_Mysore',
  'KA_Shivamogga':'KA_Shimoga',
  
 'MH_Mumbai':'MH_Mumbai City',
 'MH_Mumbai Suburban':'MH_Mumbai suburban',

 'MP_Ashoknagar': 'MP_Ashok Nagar',
 'MP_Khandwa':'Khandwa (East Nimar)',
 'MP_Khargone':'Khargone (West Nimar)',

 'OR_Bargarh':'OR_Bargarh (Baragarh)',
 'OR_Boudh':'OR_Boudh (Bauda)',
 'OR_Deogarh':'OR_Debagarh (Deogarh)',
 'OR_Kendujhar':'OR_Kendujhar (Keonjhar)',
 'OR_Nabarangapur':'OR_Nabarangpur',

 'OR_Subarnapur':'OR_Subarnapur (Sonepur)',
 

 'PB_Ferozepur':'PB_Firozpur',
 'PB_S.A.S. Nagar':'PB_Sahibzada Ajit Singh Nagar',

 'TG_Jayashankar Bhupalapally':'TG_Jayashankar Bhupalpally',
 'TG_Mahabubnagar':'TG_Mahbubnagar',
 'TG_Medchal Malkajgiri':'TG_Medchal-Malkajgiri',

 'TN_Kancheepuram':'TN_Kanchipuram',


 'TN_Thoothukkudi':'TN_Thoothukudi',
 'TN_Tirupathur':'TN_Tirupattur',
 'TN_Tiruppur':'TN_Tirupur',
 'TN_Thiruvallur': 'TN_Tiruvallur',
 'TN_Thiruvarur' : 'TN_Tiruvarur',



 
 'UP_Bagpat' : 'UP_Baghpat',
 'UP_Prayagraj': 'UP_Allahabad',
 'UP_Gautam Buddha Nagar':'UP_Gautam Buddh Nagar',
 'UP_Rae Bareli':'UP_Raebareli',
 'UP_Ayodhya':'UP_Faizabad', 
 'UP_Shrawasti':'UP_Shravasti',

 'WB_Malda':'WB_Maldah',

 'PY_Mahe':'PY_Mahé',

 
 'ML_Ribhoi':'ML_Ri Bhoi'}

dist_replace_on_main = {v: k for k, v in dist_replace_on_main.items()}
compare(shapefile_keys['dist_code'] ,main['District_Key'].replace(dist_replace_on_main))
# Out:
# {'AR_Kra Daadi',
#  'AR_Lepa Rada',
#  'AR_Lower Siang',
#  'AR_Pakke Kessang',
#  'AS_Hojai',
#  'CT_Gaurela Pendra Marwahi',
#  'CT_Uttar Bastar Kanker',
#  'DL_Shahdara',
#  'DL_South East Delhi',
#  'HR_Yamunanagar',
#  'JH_Hazaribagh',
#  'JK_Mirpur',
#  'JK_Muzaffarabad',
#  'MH_Raigad',
#  'MH_Raigarh',
#  'MN_Kakching',
#  'MN_Kangpokpi',
#  'MN_Noney',
#  'MN_Tengnoupal',
#  'MP_Agar Malwa',
#  'MP_Khandwa',
#  'MP_Khargone',
#  'SK_East District',
#  'SK_East Sikkim',
#  'SK_North District',
#  'SK_North Sikkim',
#  'SK_South District',
#  'SK_South Sikkim',
#  'SK_West District',
#  'SK_West Sikkim',
#  'TN_Chengalpattu',
#  'TN_Kallakurichi',
#  'TN_Ranipet',
#  'TN_Tenkasi',
#  'TN_Tirupathur',
#  'UP_Baghpat'}

# %%
main['District_Key'].replace(dist_replace_on_main,inplace = True)

dist_replace2_shapefile_keys = {
 'SK_East District':'SK_East Sikkim',
 'SK_North District':'SK_North Sikkim',
 'SK_South District':'SK_South Sikkim',
 'SK_West District':'SK_West Sikkim',
}

compare(shapefile_keys['dist_code'].replace(dist_replace2_shapefile_keys) ,main['District_Key'])
# Out:
# {'AR_Kra Daadi',
#  'AR_Lepa Rada',
#  'AR_Lower Siang',
#  'AR_Pakke Kessang',
#  'AS_Hojai',
#  'CT_Gaurela Pendra Marwahi',
#  'CT_Uttar Bastar Kanker',
#  'DL_Shahdara',
#  'DL_South East Delhi',
#  'HR_Yamunanagar',
#  'JH_Hazaribagh',
#  'JK_Mirpur',
#  'JK_Muzaffarabad',
#  'MH_Raigad',
#  'MH_Raigarh',
#  'MN_Kakching',
#  'MN_Kangpokpi',
#  'MN_Noney',
#  'MN_Tengnoupal',
#  'MP_Agar Malwa',
#  'MP_Khandwa',
#  'MP_Khargone',
#  'TN_Chengalpattu',
#  'TN_Kallakurichi',
#  'TN_Ranipet',
#  'TN_Tenkasi',
#  'TN_Tirupathur',
#  'UP_Baghpat'}

# %%
#demo
dist_replace2 = {
 'PB_Fazilka[15]':'PB_Fazilka',
 'TR_Khowai[16]': 'TR_Khowai',
 'TR_Sepahijala[17]':'TR_Sipahijala',
 'TR_Unokoti[18]':'TR_Unokoti',
 'UP_Shamli[19]':'UP_Shamli',
}

shapefile_keys['dist_code'].replace(dist_replace2,inplace = True)

# %% [markdown]
# ## Clustering Algorithm

# %%
main.drop(main[main['state'] == 'Ladakh'].index,inplace = True)

main['state_population'] = pd.merge(main,main[['state' ,'population_x']].groupby(['state']).sum(),on= 'state')['population_x_y']
main['ccp_district'] = main['No.CCP']*(main['population_x']/main['state_population'])
main['cce_district'] = main['No.CCE']*(main['population_x']/main['state_population'])

cluster_data = pd.DataFrame(main[['population_x','Confirmed','Active','Deceased','density','cce_district','ccp_district']])

# %%
main.dropna(inplace = True)
main.isnull().sum()
# Out:
# state                      0
# District_Key               0
# population_x               0
# area                       0
# density                    0
# Confirmed                  0
# Active                     0
# Recovered                  0
# Deceased                   0
# Migrated_Other             0
# population_y               0
# No.CCE                     0
# No.CCP                     0
# CCE per lakh population    0
# CCE per CCP                0
# state_population           0
# ccp_district               0
# cce_district               0
# dtype: int64

# %%
main.head()
# Out:
#             state      District_Key  population_x     area     density  \
# 0  Andhra Pradesh      AP_Anantapur   4540646.280  19130.0  237.357359
# 1  Andhra Pradesh       AP_Chittoor   4637560.416  15152.0  306.069193
# 2  Andhra Pradesh  AP_East Godavari   5728522.488  10807.0  530.075182
# 3  Andhra Pradesh         AP_Guntur   5436823.760  11391.0  477.291174
# 4  Andhra Pradesh  AP_Y.S.R. Kadapa   3207590.688  15359.0  208.841115
#
#    Confirmed  Active  Recovered  Deceased  Migrated_Other  population_y  \
# 0      67121     149      66377       595               0    42332781.5
# 1      85381     452      84092       837               0    42332781.5
# 2     123267     489     122142       636               0    42332781.5
# 3      74228     621      72947       660               0    42332781.5
# 4      54774     122      54197       455               0    42332781.5
#
#    No.CCE  No.CCP  CCE per lakh population  CCE per CCP  state_population  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (15,15))
fig.subplots_adjust(wspace=0.5)
fig.subplots_adjust(hspace=0.5)

x = ['population_x','Confirmed','Active','Deceased','cce_district','ccp_district']

title = ['population_x','Confirmed','Active','Deceased','cce_district','ccp_district']


for i,j,title in zip(range(1,7),x,title):`
    ax = fig.add_subplot(3, 2, i)
    dist_comp = cluster_data[j].plot(kind = 'kde',ax = ax,title = title)
# Out:
#   File "<ipython-input-45-96936018b76c>", line 10
#     for i,j,title in zip(range(1,7),x,title):`
#                                              ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import StandardScaler
ss1 = StandardScaler()
ss2 = StandardScaler()
ss3 = StandardScaler()
ss4 = StandardScaler()
ss5 = StandardScaler()
ss6 = StandardScaler()
ss7 = StandardScaler()

cluster_data['population_x'] = ss1.fit_transform(cluster_data[['population_x']])
cluster_data['Confirmed'] = ss2.fit_transform(cluster_data[['Confirmed']])
cluster_data['Active'] = ss3.fit_transform(cluster_data[['Active']])
cluster_data['Deceased'] = ss4.fit_transform(cluster_data[['Deceased']])
cluster_data['cce_district'] = ss5.fit_transform(cluster_data[['cce_district']])
cluster_data['ccp_district'] = ss6.fit_transform(cluster_data[['ccp_district']])
cluster_data['density'] = ss7.fit_transform(cluster_data[['density']])

cluster_data = cluster_data.reset_index()

#optimal clusters


X = pd.DataFrame(cluster_data)
X = X.values
from sklearn.cluster import KMeans
wcss = []
for i in range(1,35):
    km = KMeans(n_clusters = i,init='k-means++', max_iter=300, n_init=10, random_state=0)
    km.fit(X)
    wcss.append(km.inertia_)
plt.plot(range(1,35),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-af24efdd5997> in <module>
#      27 for i in range(1,35):
#      28     km = KMeans(n_clusters = i,init='k-means++', max_iter=300, n_init=10, random_state=0)
# ---> 29     km.fit(X)
#      30     wcss.append(km.inertia_)
#      31 plt.plot(range(1,35),wcss)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1028             Fitted estimator.
#    1029         """
# -> 1030         X = self._validate_data(X, accept_sparse='csr',
#    1031                                 dtype=[np.float64, np.float32],
#    1032                                 order='C', copy=self.copy_x,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
km10=KMeans(n_clusters=10,init='k-means++', max_iter=300, n_init=10, random_state=0)
y_means = km10.fit_predict(X)

cluster1['cluster'] = y_means
main['cluster'] = y_means


cluster1['score'] = cluster1['Confirmed']/cluster1['population_x'] +cluster1['Active']/cluster1['cce_district']+cluster1['population_x']/cluster1['density']
                                                 
df1.drop(columns = ['objectid', 'statecode', 'statename', 'state_ut', 'distcode',
       'distname', 'countrynam'],inplace = True)

df2 = pd.concat([df1,df1_keys],axis = 1)

cluster1['dist_key'] = main['District_Key']
df3 = pd.merge(df2,cluster1,left_on = 'dist_code',right_on = 'dist_key')
